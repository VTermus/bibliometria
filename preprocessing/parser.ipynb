# %%
import pandas as pd
import requests
from io import StringIO

# %% [markdown]
# # Scimagojr

# %%
# data for 2024 (most recent year)
url = "https://www.scimagojr.com/journalrank.php?year=2025&out=xls"
response = requests.get(url)

df = pd.read_csv(StringIO(response.text), sep=';')

# clean column names
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

print(len(df))
df.head()
# Out:
# 31136
#    rank  sourceid                                  title     type  \
# 0     1     28773     Ca-A Cancer Journal for Clinicians  journal
# 1     2     19434       MMWR Recommendations and Reports  journal
# 2     3     20315  Nature Reviews Molecular Cell Biology  journal
# 3     4     29431         Quarterly Journal of Economics  journal
# 4     5     20425          Nature Reviews Drug Discovery  journal
#
#                  issn                                         publisher  \
# 0  15424863, 00079235                           John Wiley and Sons Inc
# 1  10575987, 15458601  Centers for Disease Control and Prevention (CDC)
# 2  14710072, 14710080                                   Nature Research
# 3  00335533, 15314650                           Oxford University Press
# 4  14741784, 14741776                                   Nature Research
#
#   open_access open_access_diamond      sjr sjr_best_quartile  ...  \
# 0          No                  No  145,004                Q1  ...
# 1         Yes                  No   41,754                Q1  ...
# 2          No                  No   37,353                Q1  ...
# 3          No                  No   35,995                Q1  ...
# 4          No                  No   30,506                Q1  ...
#
#    ref._/_doc.  %female  overton  sdg         country            region  \
# 0        62,88    48,21        4   37   United States  Northern America
# 1       275,33    75,93        1    5   United States  Northern America
# 2        92,45    41,22        0   15  United Kingdom    Western Europe
# 3        69,79    25,18       35   27  United Kingdom    Western Europe
# 4        35,66    26,67        1   58  United Kingdom    Western Europe
#
#                                         publisher.1   coverage  \
# 0                           John Wiley and Sons Inc  1950-2025
# 1  Centers for Disease Control and Prevention (CDC)  1990-2024
# 2                                   Nature Research  2000-2025
# 3                           Oxford University Press  1886-2025
# 4                                   Nature Research  2002-2025
#
#                                           categories  \
# 0                     Hematology (Q1); Oncology (Q1)
# 1  Epidemiology (Q1); Health Information Manageme...
# 2          Cell Biology (Q1); Molecular Biology (Q1)
# 3                    Economics and Econometrics (Q1)
# 4  Drug Discovery (Q1); Medicine (miscellaneous) ...
#
#                                                areas
# 0                                           Medicine
# 1  Environmental Science; Health Professions; Med...
# 2       Biochemistry, Genetics and Molecular Biology
# 3                Economics, Econometrics and Finance
# 4  Medicine; Pharmacology, Toxicology and Pharmac...
#
# [5 rows x 27 columns]

# %%
df.to_csv('sjr_journals_2024.csv', index=False)

# %% [markdown]
# # Web of Science

# %%
#!pip install fake-useragent
# Out:
# Collecting fake-useragent
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: fake-useragent
# Successfully installed fake-useragent-2.2.0

# %%
import os
import time
import random
import requests
import re
from bs4 import BeautifulSoup
from pprint import pprint
from fake_useragent import UserAgent
from tqdm.auto import tqdm

# %%
# check adequateness
session = requests.session()
ua = UserAgent()
headers = {'User-Agent': ua.random}
response = session.get('https://wos-journal.info/?jsearch=&page=2', headers=headers)
print(response.status_code)
# Out:
# 200

# %%
# base URL pattern
base_url = "https://wos-journal.info/?jsearch=&page={}"

journal_links = []

# %%
# process all 23711 journals
for page in tqdm(range(0, 2371), desc="Processing pages"):
    url = base_url.format(page)
    response = session.get(url, headers=headers)

    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        continue

    soup = BeautifulSoup(response.content, 'html.parser')

    # find all journal pages
    journal_pages = soup.find_all('div', class_=lambda x: x and x.startswith('cardj'))

    for page in journal_pages:
        link = page.find('a', href=lambda href: href and 'journalid' in href)
        full_url = 'https://wos-journal.info' + link['href'][1:]
        # print(full_url)
        journal_links.append(full_url)

    time.sleep(random.choice([0.5, 0.4, 0.3]))
# Out:
# Processing pages:   0%|          | 0/2371 [00:00<?, ?it/s]

# %%
# forgot the last one
journal_links.append("https://wos-journal.info/journalid/23550")

# %%
print(f"Total links collected: {len(journal_links)}")
# Out:
# Total links collected: 23711

# %%
journals = []

for i, page in tqdm(enumerate(journal_links), desc="Processing pages"):
    try:
        response = session.get(page, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')

        # data for each journal
        journal_data = {}

        # title
        title_div = soup.find('div', class_='title title2 col-12 col-md-12 h5 py-5')
        if title_div and title_div.find('a'):
          title_text = title_div.find('a').text.strip()
          journal_data['title'] = title_text

        journal_data['url'] = page

        # journal features mapping
        features = {
            'Abbreviation': 'abbreviation',
            'ISSN:': 'issn',
            'eISSN:': 'eissn',
            'Category:': 'category',
            'WoS Core Citation Indexes:': 'wos_index',
            'Journal Impact Factor (JIF):': 'jif',
            '5-year Impact Factor:': '5_year_jif',
            'Open Access Support:': 'open_access',
            'Country:': 'country',
            'Status in WoS core:': 'wos_status',
            'Publisher:': 'publisher'
        }

        # find all features
        titles = soup.find_all('div', class_='title')

        for title_div in titles:
            title_text = title_div.text.strip()
            content_div = title_div.find_next_sibling('div', class_='content')

            if content_div:
                content_text = content_div.text.strip()

                # check each feature
                for feature, col_name in features.items():
                    if feature in title_text:
                        journal_data[col_name] = content_text

                # best_ranking
                if 'Best ranking' in title_text:
                    best_ranking = content_text.split('║')[0].strip()
                    journal_data['best_ranking'] = best_ranking

                    # percentage for quartile
                    percentage_span = content_div.find('span', class_='badge badge-primary')

                    if percentage_span:
                        percentage_text = percentage_span.text.strip().replace('Percentage rank: ', '')
                        journal_data['percentage'] = percentage_text

        journals.append(journal_data)

    except Exception as e:
        print(f"Error with {page}: {e}")
        continue

    time.sleep(random.choice([0.4, 0.3, 0.2]))
# Out:
# Processing pages: 0it [00:00, ?it/s]

# %%
journals
# Out:
# [{'title': 'CA-A CANCER JOURNAL FOR CLINICIANS',
#   'url': 'https://wos-journal.info/journalid/1',
#   'abbreviation': 'CA-CANCER J CLIN',
#   'issn': '1542-4863',
#   'eissn': '1542-4863',
#   'category': 'ONCOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '232.4',
#   '5_year_jif': '353',
#   'best_ranking': 'ONCOLOGY',
#   'percentage': '99.7%',
#   'open_access': 'Fully Open Access ― It may take a publication fee. For more info, check it on DOAJ.ORG',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'NATURE REVIEWS MICROBIOLOGY',
#   'url': 'https://wos-journal.info/journalid/13',
#   'abbreviation': 'NAT REV MICROBIOL',
#   'issn': '1740-1534',
#   'eissn': '1740-1534',
#   'category': 'MICROBIOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '103.3',
#   '5_year_jif': '99.1',
#   'best_ranking': 'MICROBIOLOGY',
#   'percentage': '99.4%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'NATURE REVIEWS DRUG DISCOVERY',
#   'url': 'https://wos-journal.info/journalid/6',
#   'abbreviation': 'NAT REV DRUG DISCOV',
#   'issn': '1474-1784',
#   'eissn': '1474-1784',
#   'category': 'PHARMACOLOGY & PHARMACY - SCIE BIOTECHNOLOGY & APPLIED MICROBIOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '101.8',
#   '5_year_jif': '129.8',
#   'best_ranking': 'PHARMACOLOGY & PHARMACY',
#   'percentage': '99.7%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'NATURE REVIEWS MOLECULAR CELL BIOLOGY',
#   'url': 'https://wos-journal.info/journalid/5',
#   'abbreviation': 'NAT REV MOL CELL BIO',
#   'issn': '1471-0080',
#   'eissn': '1471-0080',
#   'category': 'CELL BIOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '90.2',
#   '5_year_jif': '128.7',
#   'best_ranking': 'CELL BIOLOGY',
#   'percentage': '99.5%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Kidney International Supplements',
#   'url': 'https://wos-journal.info/journalid/7096',
#   'abbreviation': 'KIDNEY INT SUPPL',
#   'issn': '2157-1716',
#   'eissn': '2157-1716',
#   'category': 'UROLOGY & NEPHROLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '89.6',
#   '5_year_jif': '26',
#   'best_ranking': 'UROLOGY & NEPHROLOGY',
#   'percentage': '99.2%',
#   'open_access': 'Subscription',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'LANCET',
#   'url': 'https://wos-journal.info/journalid/2',
#   'abbreviation': 'LANCET',
#   'issn': '1474-547X',
#   'eissn': '1474-547X',
#   'category': 'MEDICINE, GENERAL & INTERNAL - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '88.5',
#   '5_year_jif': '104.8',
#   'best_ranking': 'MEDICINE, GENERAL & INTERNAL',
#   'percentage': '99.7%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Nature Reviews Materials',
#   'url': 'https://wos-journal.info/journalid/15',
#   'abbreviation': 'NAT REV MATER',
#   'issn': '2058-8437',
#   'eissn': '2058-8437',
#   'category': 'NANOSCIENCE & NANOTECHNOLOGY - SCIE MATERIALS SCIENCE, MULTIDISCIPLINARY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '86.2',
#   '5_year_jif': '99.8',
#   'best_ranking': 'NANOSCIENCE & NANOTECHNOLOGY',
#   'percentage': '99.8%',
#   'open_access': 'Subscription',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Nature Reviews Clinical Oncology',
#   'url': 'https://wos-journal.info/journalid/26',
#   'abbreviation': 'NAT REV CLIN ONCOL',
#   'issn': '1759-4782',
#   'eissn': '1759-4782',
#   'category': 'ONCOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '82.2',
#   '5_year_jif': '89.9',
#   'best_ranking': 'ONCOLOGY',
#   'percentage': '99.4%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'NEW ENGLAND JOURNAL OF MEDICINE',
#   'url': 'https://wos-journal.info/journalid/3',
#   'abbreviation': 'NEW ENGL J MED',
#   'issn': '1533-4406',
#   'eissn': '1533-4406',
#   'category': 'MEDICINE, GENERAL & INTERNAL - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '78.5',
#   '5_year_jif': '84.9',
#   'best_ranking': 'MEDICINE, GENERAL & INTERNAL',
#   'percentage': '99.4%',
#   'open_access': 'Subscription',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Nature Reviews Earth & Environment',
#   'url': 'https://wos-journal.info/journalid/72',
#   'abbreviation': 'NAT REV EARTH ENV',
#   'issn': '2662-138X',
#   'eissn': '2662-138X',
#   'category': 'ENVIRONMENTAL SCIENCES - SCIE GEOSCIENCES, MULTIDISCIPLINARY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '71.5',
#   '5_year_jif': '73.7',
#   'best_ranking': 'GEOSCIENCES, MULTIDISCIPLINARY',
#   'percentage': '99.7%',
#   'open_access': 'Subscription',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'NATURE REVIEWS CANCER',
#   'url': 'https://wos-journal.info/journalid/20',
#   'abbreviation': 'NAT REV CANCER',
#   'issn': '1474-1768',
#   'eissn': '1474-1768',
#   'category': 'ONCOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '66.8',
#   '5_year_jif': '81',
#   'best_ranking': 'ONCOLOGY',
#   'percentage': '99.1%',
#   'open_access': 'Subscription',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'World Psychiatry',
#   'url': 'https://wos-journal.info/journalid/12',
#   'abbreviation': 'WORLD PSYCHIATRY',
#   'issn': '2051-5545',
#   'eissn': '2051-5545',
#   'category': 'PSYCHIATRY - SCIE PSYCHIATRY - SSCI',
#   'wos_index': 'SCIE - Science Citation Index ExpandedSSCI - Social Sciences Citation Index',
#   'jif': '65.8',
#   '5_year_jif': '60',
#   'best_ranking': 'PSYCHIATRY',
#   'percentage': '99.7%',
#   'open_access': 'Subscription',
#   'country': 'ITALY',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'ANNALS OF ONCOLOGY',
#   'url': 'https://wos-journal.info/journalid/33',
#   'abbreviation': 'ANN ONCOL',
#   'issn': '1569-8041',
#   'eissn': '1569-8041',
#   'category': 'ONCOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '65.4',
#   '5_year_jif': '46.8',
#   'best_ranking': 'ONCOLOGY',
#   'percentage': '98.8%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'NETHERLANDS',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Living Reviews in Relativity',
#   'url': 'https://wos-journal.info/journalid/51',
#   'abbreviation': 'LIVING REV RELATIV',
#   'issn': '1433-8351',
#   'eissn': '1433-8351',
#   'category': 'PHYSICS, PARTICLES & FIELDS - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '62.5',
#   '5_year_jif': '52.4',
#   'best_ranking': 'PHYSICS, PARTICLES & FIELDS',
#   'percentage': '96.8%',
#   'open_access': 'Fully Open Access ― It may take a publication fee. For more info, check it on DOAJ.ORG',
#   'country': 'GERMANY',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'NATURE REVIEWS IMMUNOLOGY',
#   'url': 'https://wos-journal.info/journalid/7',
#   'abbreviation': 'NAT REV IMMUNOL',
#   'issn': '1474-1741',
#   'eissn': '1474-1741',
#   'category': 'IMMUNOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '60.9',
#   '5_year_jif': '77.6',
#   'best_ranking': 'IMMUNOLOGY',
#   'percentage': '99.5%',
#   'open_access': 'Subscription',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Nature Reviews Disease Primers',
#   'url': 'https://wos-journal.info/journalid/25',
#   'abbreviation': 'NAT REV DIS PRIMERS',
#   'issn': '2056-676X',
#   'eissn': '2056-676X',
#   'category': 'MEDICINE, GENERAL & INTERNAL - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '60.6',
#   '5_year_jif': '104.8',
#   'best_ranking': 'MEDICINE, GENERAL & INTERNAL',
#   'percentage': '99.1%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Nature Energy',
#   'url': 'https://wos-journal.info/journalid/23',
#   'abbreviation': 'NAT ENERGY',
#   'issn': '2058-7546',
#   'eissn': '2058-7546',
#   'category': 'MATERIALS SCIENCE, MULTIDISCIPLINARY - SCIE ENERGY & FUELS - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '60.1',
#   '5_year_jif': '68.9',
#   'best_ranking': 'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#   'percentage': '99.6%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'MMWR Recommendations and Reports',
#   'url': 'https://wos-journal.info/journalid/74',
#   'abbreviation': 'N/A',
#   'issn': '1545-8601',
#   'eissn': '1545-8601',
#   'category': 'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': 'N/A',
#   '5_year_jif': 'N/A',
#   'best_ranking': 'Unavailable',
#   'percentage': '99.8%',
#   'open_access': 'Fully Open Access ― It may take a publication fee. For more info, check it on DOAJ.ORG',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'NATURE REVIEWS METHODS PRIMERS',
#   'url': 'https://wos-journal.info/journalid/23583',
#   'abbreviation': 'NAT REV METHOD PRIME',
#   'issn': '2662-8449',
#   'eissn': '2662-8449',
#   'category': 'Multidisciplinary Sciences - ESCI',
#   'wos_index': 'ESCI - Emerging Sources Citation Index',
#   'jif': '56',
#   '5_year_jif': '66.9',
#   'best_ranking': 'MULTIDISCIPLINARY SCIENCES',
#   'percentage': '99.3%',
#   'open_access': 'Subscription',
#   'country': 'N/A',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'CHEMICAL REVIEWS',
#   'url': 'https://wos-journal.info/journalid/18',
#   'abbreviation': 'CHEM REV',
#   'issn': '1520-6890',
#   'eissn': '1520-6890',
#   'category': 'CHEMISTRY, MULTIDISCIPLINARY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '55.8',
#   '5_year_jif': '67.5',
#   'best_ranking': 'CHEMISTRY, MULTIDISCIPLINARY',
#   'percentage': '99.6%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'JAMA-JOURNAL OF THE AMERICAN MEDICAL ASSOCIATION',
#   'url': 'https://wos-journal.info/journalid/4',
#   'abbreviation': 'JAMA-J AM MED ASSOC',
#   'issn': '1538-3598',
#   'eissn': '1538-3598',
#   'category': 'MEDICINE, GENERAL & INTERNAL - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '55',
#   '5_year_jif': '64.7',
#   'best_ranking': 'MEDICINE, GENERAL & INTERNAL',
#   'percentage': '98.8%',
#   'open_access': 'Subscription',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Signal Transduction and Targeted Therapy',
#   'url': 'https://wos-journal.info/journalid/67',
#   'abbreviation': 'SIGNAL TRANSDUCT TAR',
#   'issn': '2059-3635',
#   'eissn': '2059-3635',
#   'category': 'CELL BIOLOGY - SCIE BIOCHEMISTRY & MOLECULAR BIOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '52.7',
#   '5_year_jif': '52.2',
#   'best_ranking': 'CELL BIOLOGY',
#   'percentage': '99.7%',
#   'open_access': 'Fully Open Access ― It may take a publication fee. For more info, check it on DOAJ.ORG',
#   'country': 'PEOPLES R CHINA',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'NATURE REVIEWS GENETICS',
#   'url': 'https://wos-journal.info/journalid/30',
#   'abbreviation': 'NAT REV GENET',
#   'issn': '1471-0064',
#   'eissn': '1471-0064',
#   'category': 'GENETICS & HEREDITY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '52',
#   '5_year_jif': '57.1',
#   'best_ranking': 'GENETICS & HEREDITY',
#   'percentage': '99.5%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Nature Reviews Chemistry',
#   'url': 'https://wos-journal.info/journalid/82',
#   'abbreviation': 'NAT REV CHEM',
#   'issn': '2397-3358',
#   'eissn': '2397-3358',
#   'category': 'CHEMISTRY, MULTIDISCIPLINARY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '51.7',
#   '5_year_jif': '49.4',
#   'best_ranking': 'CHEMISTRY, MULTIDISCIPLINARY',
#   'percentage': '99.2%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Nature Reviews Gastroenterology & Hepatology',
#   'url': 'https://wos-journal.info/journalid/16',
#   'abbreviation': 'NAT REV GASTRO HEPAT',
#   'issn': '1759-5053',
#   'eissn': '1759-5053',
#   'category': 'GASTROENTEROLOGY & HEPATOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '51',
#   '5_year_jif': '72.4',
#   'best_ranking': 'GASTROENTEROLOGY & HEPATOLOGY',
#   'percentage': '99.3%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'NATURE MEDICINE',
#   'url': 'https://wos-journal.info/journalid/10',
#   'abbreviation': 'NAT MED',
#   'issn': '1546-170X',
#   'eissn': '1546-170X',
#   'category': 'MEDICINE, RESEARCH & EXPERIMENTAL - SCIE CELL BIOLOGY - SCIE BIOCHEMISTRY & MOLECULAR BIOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '50',
#   '5_year_jif': '52.4',
#   'best_ranking': 'MEDICINE, RESEARCH & EXPERIMENTAL',
#   'percentage': '99.5%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'MMWR Surveillance Summaries',
#   'url': 'https://wos-journal.info/journalid/110',
#   'abbreviation': 'MMWR SURVEILL SUMM',
#   'issn': '1545-8636',
#   'eissn': '1545-8636',
#   'category': 'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '49.8',
#   '5_year_jif': '34.1',
#   'best_ranking': 'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH',
#   'percentage': '99.5%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'NATURE',
#   'url': 'https://wos-journal.info/journalid/21',
#   'abbreviation': 'NATURE',
#   'issn': '1476-4687',
#   'eissn': '1476-4687',
#   'category': 'MULTIDISCIPLINARY SCIENCES - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '48.5',
#   '5_year_jif': '55',
#   'best_ranking': 'MULTIDISCIPLINARY SCIENCES',
#   'percentage': '98.5%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'IEEE Communications Surveys and Tutorials',
#   'url': 'https://wos-journal.info/journalid/84',
#   'abbreviation': 'IEEE COMMUN SURV TUT',
#   'issn': '1553-877X',
#   'eissn': '1553-877X',
#   'category': 'TELECOMMUNICATIONS - SCIE COMPUTER SCIENCE, INFORMATION SYSTEMS - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '46.7',
#   '5_year_jif': '42.8',
#   'best_ranking': 'TELECOMMUNICATIONS',
#   'percentage': '99.6%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'SCIENCE',
#   'url': 'https://wos-journal.info/journalid/27',
#   'abbreviation': 'SCIENCE',
#   'issn': '1095-9203',
#   'eissn': '1095-9203',
#   'category': 'MULTIDISCIPLINARY SCIENCES - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '45.8',
#   '5_year_jif': '49.7',
#   'best_ranking': 'MULTIDISCIPLINARY SCIENCES',
#   'percentage': '97.8%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'LANCET NEUROLOGY',
#   'url': 'https://wos-journal.info/journalid/29',
#   'abbreviation': 'LANCET NEUROL',
#   'issn': '1474-4465',
#   'eissn': '1474-4465',
#   'category': 'CLINICAL NEUROLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '45.5',
#   '5_year_jif': '56.2',
#   'best_ranking': 'CLINICAL NEUROLOGY',
#   'percentage': '99.6%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'REVIEWS OF MODERN PHYSICS',
#   'url': 'https://wos-journal.info/journalid/36',
#   'abbreviation': 'REV MOD PHYS',
#   'issn': '1539-0756',
#   'eissn': '1539-0756',
#   'category': 'PHYSICS, MULTIDISCIPLINARY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '44.8',
#   '5_year_jif': '56.3',
#   'best_ranking': 'PHYSICS, MULTIDISCIPLINARY',
#   'percentage': '99.1%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Nature Catalysis',
#   'url': 'https://wos-journal.info/journalid/56',
#   'abbreviation': 'NAT CATAL',
#   'issn': '2520-1158',
#   'eissn': '2520-1158',
#   'category': 'CHEMISTRY, PHYSICAL - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '44.6',
#   '5_year_jif': '47.4',
#   'best_ranking': 'CHEMISTRY, PHYSICAL',
#   'percentage': '99.5%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'CANCER CELL',
#   'url': 'https://wos-journal.info/journalid/65',
#   'abbreviation': 'CANCER CELL',
#   'issn': '1878-3686',
#   'eissn': '1878-3686',
#   'category': 'ONCOLOGY - SCIE CELL BIOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '44.5',
#   '5_year_jif': '47.2',
#   'best_ranking': 'ONCOLOGY',
#   'percentage': '98.5%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Nature Reviews Cardiology',
#   'url': 'https://wos-journal.info/journalid/38',
#   'abbreviation': 'NAT REV CARDIOL',
#   'issn': '1759-5010',
#   'eissn': '1759-5010',
#   'category': 'CARDIAC & CARDIOVASCULAR SYSTEMS - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '44.2',
#   '5_year_jif': '52.9',
#   'best_ranking': 'CARDIAC & CARDIOVASCULAR SYSTEMS',
#   'percentage': '99.6%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'BMJ-British Medical Journal',
#   'url': 'https://wos-journal.info/journalid/9',
#   'abbreviation': 'BMJ-BRIT MED J',
#   'issn': '1756-1833',
#   'eissn': '1756-1833',
#   'category': 'MEDICINE, GENERAL & INTERNAL - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '42.7',
#   '5_year_jif': '76.1',
#   'best_ranking': 'MEDICINE, GENERAL & INTERNAL',
#   'percentage': '98.5%',
#   'open_access': 'Fully Open Access ― It may take a publication fee. For more info, check it on DOAJ.ORG',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'CELL',
#   'url': 'https://wos-journal.info/journalid/24',
#   'abbreviation': 'CELL',
#   'issn': '1097-4172',
#   'eissn': '1097-4172',
#   'category': 'CELL BIOLOGY - SCIE BIOCHEMISTRY & MOLECULAR BIOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '42.5',
#   '5_year_jif': '48.9',
#   'best_ranking': 'CELL BIOLOGY',
#   'percentage': '99.1%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'JOURNAL OF CLINICAL ONCOLOGY',
#   'url': 'https://wos-journal.info/journalid/35',
#   'abbreviation': 'J CLIN ONCOL',
#   'issn': '1527-7755',
#   'eissn': '1527-7755',
#   'category': 'ONCOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '41.9',
#   '5_year_jif': '37.7',
#   'best_ranking': 'ONCOLOGY',
#   'percentage': '98.2%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Lancet Diabetes & Endocrinology',
#   'url': 'https://wos-journal.info/journalid/47',
#   'abbreviation': 'LANCET DIABETES ENDO',
#   'issn': '2213-8595',
#   'eissn': '2213-8595',
#   'category': 'ENDOCRINOLOGY & METABOLISM - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '41.8',
#   '5_year_jif': '41.7',
#   'best_ranking': 'ENDOCRINOLOGY & METABOLISM',
#   'percentage': '99.5%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'NATURE BIOTECHNOLOGY',
#   'url': 'https://wos-journal.info/journalid/22',
#   'abbreviation': 'NAT BIOTECHNOL',
#   'issn': '1546-1696',
#   'eissn': '1546-1696',
#   'category': 'BIOTECHNOLOGY & APPLIED MICROBIOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '41.7',
#   '5_year_jif': '59.5',
#   'best_ranking': 'BIOTECHNOLOGY & APPLIED MICROBIOLOGY',
#   'percentage': '98.9%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Nature Electronics',
#   'url': 'https://wos-journal.info/journalid/87',
#   'abbreviation': 'NAT ELECTRON',
#   'issn': '2520-1131',
#   'eissn': '2520-1131',
#   'category': 'ENGINEERING, ELECTRICAL & ELECTRONIC - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '40.9',
#   '5_year_jif': '42',
#   'best_ranking': 'ENGINEERING, ELECTRICAL & ELECTRONIC',
#   'percentage': '99.7%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Journal of Hematology & Oncology',
#   'url': 'https://wos-journal.info/journalid/155',
#   'abbreviation': 'J HEMATOL ONCOL',
#   'issn': '1756-8722',
#   'eissn': '1756-8722',
#   'category': 'HEMATOLOGY - SCIE ONCOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '40.4',
#   '5_year_jif': '34.4',
#   'best_ranking': 'ONCOLOGY',
#   'percentage': '99%',
#   'open_access': 'Fully Open Access ― It may take a publication fee. For more info, check it on DOAJ.ORG',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'PROGRESS IN MATERIALS SCIENCE',
#   'url': 'https://wos-journal.info/journalid/39',
#   'abbreviation': 'PROG MATER SCI',
#   'issn': '1873-2208',
#   'eissn': '1873-2208',
#   'category': 'MATERIALS SCIENCE, MULTIDISCIPLINARY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '40',
#   '5_year_jif': '44.8',
#   'best_ranking': 'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#   'percentage': '99.3%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Nature Reviews Endocrinology',
#   'url': 'https://wos-journal.info/journalid/42',
#   'abbreviation': 'NAT REV ENDOCRINOL',
#   'issn': '1759-5037',
#   'eissn': '1759-5037',
#   'category': 'ENDOCRINOLOGY & METABOLISM - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '40',
#   '5_year_jif': '47',
#   'best_ranking': 'ENDOCRINOLOGY & METABOLISM',
#   'percentage': '99%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Nature Reviews Nephrology',
#   'url': 'https://wos-journal.info/journalid/52',
#   'abbreviation': 'NAT REV NEPHROL',
#   'issn': '1759-507X',
#   'eissn': '1759-507X',
#   'category': 'UROLOGY & NEPHROLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '39.8',
#   '5_year_jif': '44.5',
#   'best_ranking': 'UROLOGY & NEPHROLOGY',
#   'percentage': '98.5%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Nature Reviews Physics',
#   'url': 'https://wos-journal.info/journalid/75',
#   'abbreviation': 'NAT REV PHYS',
#   'issn': '2522-5820',
#   'eissn': '2522-5820',
#   'category': 'PHYSICS, MULTIDISCIPLINARY - SCIE PHYSICS, APPLIED - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '39.5',
#   '5_year_jif': '53.2',
#   'best_ranking': 'PHYSICS, MULTIDISCIPLINARY',
#   'percentage': '99.5%',
#   'open_access': 'Subscription',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'CHEMICAL SOCIETY REVIEWS',
#   'url': 'https://wos-journal.info/journalid/28',
#   'abbreviation': 'CHEM SOC REV',
#   'issn': '1460-4744',
#   'eissn': '1460-4744',
#   'category': 'CHEMISTRY, MULTIDISCIPLINARY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '39',
#   '5_year_jif': '50.1',
#   'best_ranking': 'CHEMISTRY, MULTIDISCIPLINARY',
#   'percentage': '98.7%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'Lancet Gastroenterology & Hepatology',
#   'url': 'https://wos-journal.info/journalid/46',
#   'abbreviation': 'LANCET GASTROENTEROL',
#   'issn': '2468-1253',
#   'eissn': '2468-1253',
#   'category': 'GASTROENTEROLOGY & HEPATOLOGY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '38.6',
#   '5_year_jif': '34',
#   'best_ranking': 'GASTROENTEROLOGY & HEPATOLOGY',
#   'percentage': '98.6%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'CIRCULATION',
#   'url': 'https://wos-journal.info/journalid/58',
#   'abbreviation': 'CIRCULATION',
#   'issn': '1524-4539',
#   'eissn': '1524-4539',
#   'category': 'CARDIAC & CARDIOVASCULAR SYSTEMS - SCIE PERIPHERAL VASCULAR DISEASE - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '38.6',
#   '5_year_jif': '35.9',
#   'best_ranking': 'PERIPHERAL VASCULAR DISEASE',
#   'percentage': '99%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'UNITED STATES',
#   'wos_status': 'Active',
#   'publisher': 'N/A'},
#  {'title': 'NATURE MATERIALS',
#   'url': 'https://wos-journal.info/journalid/41',
#   'abbreviation': 'NAT MATER',
#   'issn': '1476-4660',
#   'eissn': '1476-4660',
#   'category': 'CHEMISTRY, PHYSICAL - SCIE PHYSICS, APPLIED - SCIE PHYSICS, CONDENSED MATTER - SCIE MATERIALS SCIENCE, MULTIDISCIPLINARY - SCIE',
#   'wos_index': 'SCIE - Science Citation Index Expanded',
#   'jif': '38.5',
#   '5_year_jif': '46.8',
#   'best_ranking': 'PHYSICS, CONDENSED MATTER',
#   'percentage': '98.7%',
#   'open_access': 'Hybrid and Open Access Support',
#   'country': 'ENGLAND',
#   'wos_status': 'Active',
#   'publisher': 'N/A'}]

# %%
df = pd.DataFrame(journals)
print(df)

df.to_csv('wos_journals_data.csv', index=False)
# Out:
#                                                title  \
# 0                 CA-A CANCER JOURNAL FOR CLINICIANS
# 1                        NATURE REVIEWS MICROBIOLOGY
# 2                      NATURE REVIEWS DRUG DISCOVERY
# 3              NATURE REVIEWS MOLECULAR CELL BIOLOGY
# 4                   Kidney International Supplements
# 5                                             LANCET
# 6                           Nature Reviews Materials
# 7                   Nature Reviews Clinical Oncology
# 8                    NEW ENGLAND JOURNAL OF MEDICINE
# 9                 Nature Reviews Earth & Environment
# 10                             NATURE REVIEWS CANCER
# 11                                  World Psychiatry
# 12                                ANNALS OF ONCOLOGY
# 13                      Living Reviews in Relativity
# 14                         NATURE REVIEWS IMMUNOLOGY
# 15                    Nature Reviews Disease Primers
# 16                                     Nature Energy
# 17                  MMWR Recommendations and Reports
# 18                    NATURE REVIEWS METHODS PRIMERS
# 19                                  CHEMICAL REVIEWS
# 20  JAMA-JOURNAL OF THE AMERICAN MEDICAL ASSOCIATION
# 21          Signal Transduction and Targeted Therapy
# 22                           NATURE REVIEWS GENETICS
# 23                          Nature Reviews Chemistry
# 24      Nature Reviews Gastroenterology & Hepatology
# 25                                   NATURE MEDICINE
# 26                       MMWR Surveillance Summaries
# 27                                            NATURE
# 28         IEEE Communications Surveys and Tutorials
# 29                                           SCIENCE
# 30                                  LANCET NEUROLOGY
# 31                         REVIEWS OF MODERN PHYSICS
# 32                                  Nature Catalysis
# 33                                       CANCER CELL
# 34                         Nature Reviews Cardiology
# 35                       BMJ-British Medical Journal
# 36                                              CELL
# 37                      JOURNAL OF CLINICAL ONCOLOGY
# 38                   Lancet Diabetes & Endocrinology
# 39                              NATURE BIOTECHNOLOGY
# 40                                Nature Electronics
# 41                  Journal of Hematology & Oncology
# 42                     PROGRESS IN MATERIALS SCIENCE
# 43                      Nature Reviews Endocrinology
# 44                         Nature Reviews Nephrology
# 45                            Nature Reviews Physics
# 46                          CHEMICAL SOCIETY REVIEWS
# 47              Lancet Gastroenterology & Hepatology
# 48                                       CIRCULATION
# 49                                  NATURE MATERIALS
#
#                                          url          abbreviation       issn  \
# 0       https://wos-journal.info/journalid/1      CA-CANCER J CLIN  1542-4863
# 1      https://wos-journal.info/journalid/13     NAT REV MICROBIOL  1740-1534
# 2       https://wos-journal.info/journalid/6   NAT REV DRUG DISCOV  1474-1784
# 3       https://wos-journal.info/journalid/5  NAT REV MOL CELL BIO  1471-0080
# 4    https://wos-journal.info/journalid/7096      KIDNEY INT SUPPL  2157-1716
# 5       https://wos-journal.info/journalid/2                LANCET  1474-547X
# 6      https://wos-journal.info/journalid/15         NAT REV MATER  2058-8437
# 7      https://wos-journal.info/journalid/26    NAT REV CLIN ONCOL  1759-4782
# 8       https://wos-journal.info/journalid/3        NEW ENGL J MED  1533-4406
# 9      https://wos-journal.info/journalid/72     NAT REV EARTH ENV  2662-138X
# 10     https://wos-journal.info/journalid/20        NAT REV CANCER  1474-1768
# 11     https://wos-journal.info/journalid/12      WORLD PSYCHIATRY  2051-5545
# 12     https://wos-journal.info/journalid/33             ANN ONCOL  1569-8041
# 13     https://wos-journal.info/journalid/51    LIVING REV RELATIV  1433-8351
# 14      https://wos-journal.info/journalid/7       NAT REV IMMUNOL  1474-1741
# 15     https://wos-journal.info/journalid/25   NAT REV DIS PRIMERS  2056-676X
# 16     https://wos-journal.info/journalid/23            NAT ENERGY  2058-7546
# 17     https://wos-journal.info/journalid/74                   N/A  1545-8601
# 18  https://wos-journal.info/journalid/23583  NAT REV METHOD PRIME  2662-8449
# 19     https://wos-journal.info/journalid/18              CHEM REV  1520-6890
# 20      https://wos-journal.info/journalid/4   JAMA-J AM MED ASSOC  1538-3598
# 21     https://wos-journal.info/journalid/67  SIGNAL TRANSDUCT TAR  2059-3635
# 22     https://wos-journal.info/journalid/30         NAT REV GENET  1471-0064
# 23     https://wos-journal.info/journalid/82          NAT REV CHEM  2397-3358
# 24     https://wos-journal.info/journalid/16  NAT REV GASTRO HEPAT  1759-5053
# 25     https://wos-journal.info/journalid/10               NAT MED  1546-170X
# 26    https://wos-journal.info/journalid/110    MMWR SURVEILL SUMM  1545-8636
# 27     https://wos-journal.info/journalid/21                NATURE  1476-4687
# 28     https://wos-journal.info/journalid/84  IEEE COMMUN SURV TUT  1553-877X
# 29     https://wos-journal.info/journalid/27               SCIENCE  1095-9203
# 30     https://wos-journal.info/journalid/29         LANCET NEUROL  1474-4465
# 31     https://wos-journal.info/journalid/36          REV MOD PHYS  1539-0756
# 32     https://wos-journal.info/journalid/56             NAT CATAL  2520-1158
# 33     https://wos-journal.info/journalid/65           CANCER CELL  1878-3686
# 34     https://wos-journal.info/journalid/38       NAT REV CARDIOL  1759-5010
# 35      https://wos-journal.info/journalid/9        BMJ-BRIT MED J  1756-1833
# 36     https://wos-journal.info/journalid/24                  CELL  1097-4172
# 37     https://wos-journal.info/journalid/35          J CLIN ONCOL  1527-7755
# 38     https://wos-journal.info/journalid/47  LANCET DIABETES ENDO  2213-8595
# 39     https://wos-journal.info/journalid/22        NAT BIOTECHNOL  1546-1696
# 40     https://wos-journal.info/journalid/87          NAT ELECTRON  2520-1131
# 41    https://wos-journal.info/journalid/155       J HEMATOL ONCOL  1756-8722
# 42     https://wos-journal.info/journalid/39        PROG MATER SCI  1873-2208
# 43     https://wos-journal.info/journalid/42    NAT REV ENDOCRINOL  1759-5037
# 44     https://wos-journal.info/journalid/52       NAT REV NEPHROL  1759-507X
# 45     https://wos-journal.info/journalid/75          NAT REV PHYS  2522-5820
# 46     https://wos-journal.info/journalid/28          CHEM SOC REV  1460-4744
# 47     https://wos-journal.info/journalid/46  LANCET GASTROENTEROL  2468-1253
# 48     https://wos-journal.info/journalid/58           CIRCULATION  1524-4539
# 49     https://wos-journal.info/journalid/41             NAT MATER  1476-4660
#
#         eissn                                           category  \
# 0   1542-4863                                    ONCOLOGY - SCIE
# 1   1740-1534                                MICROBIOLOGY - SCIE
# 2   1474-1784  PHARMACOLOGY & PHARMACY - SCIE BIOTECHNOLOGY &...
# 3   1471-0080                                CELL BIOLOGY - SCIE
# 4   2157-1716                        UROLOGY & NEPHROLOGY - SCIE
# 5   1474-547X                MEDICINE, GENERAL & INTERNAL - SCIE
# 6   2058-8437  NANOSCIENCE & NANOTECHNOLOGY - SCIE MATERIALS ...
# 7   1759-4782                                    ONCOLOGY - SCIE
# 8   1533-4406                MEDICINE, GENERAL & INTERNAL - SCIE
# 9   2662-138X  ENVIRONMENTAL SCIENCES - SCIE GEOSCIENCES, MUL...
# 10  1474-1768                                    ONCOLOGY - SCIE
# 11  2051-5545                PSYCHIATRY - SCIE PSYCHIATRY - SSCI
# 12  1569-8041                                    ONCOLOGY - SCIE
# 13  1433-8351                 PHYSICS, PARTICLES & FIELDS - SCIE
# 14  1474-1741                                  IMMUNOLOGY - SCIE
# 15  2056-676X                MEDICINE, GENERAL & INTERNAL - SCIE
# 16  2058-7546  MATERIALS SCIENCE, MULTIDISCIPLINARY - SCIE EN...
# 17  1545-8601  PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH - ...
# 18  2662-8449                  Multidisciplinary Sciences - ESCI
# 19  1520-6890                CHEMISTRY, MULTIDISCIPLINARY - SCIE
# 20  1538-3598                MEDICINE, GENERAL & INTERNAL - SCIE
# 21  2059-3635  CELL BIOLOGY - SCIE BIOCHEMISTRY & MOLECULAR B...
# 22  1471-0064                         GENETICS & HEREDITY - SCIE
# 23  2397-3358                CHEMISTRY, MULTIDISCIPLINARY - SCIE
# 24  1759-5053               GASTROENTEROLOGY & HEPATOLOGY - SCIE
# 25  1546-170X  MEDICINE, RESEARCH & EXPERIMENTAL - SCIE CELL ...
# 26  1545-8636  PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH - ...
# 27  1476-4687                  MULTIDISCIPLINARY SCIENCES - SCIE
# 28  1553-877X  TELECOMMUNICATIONS - SCIE COMPUTER SCIENCE, IN...
# 29  1095-9203                  MULTIDISCIPLINARY SCIENCES - SCIE
# 30  1474-4465                          CLINICAL NEUROLOGY - SCIE
# 31  1539-0756                  PHYSICS, MULTIDISCIPLINARY - SCIE
# 32  2520-1158                         CHEMISTRY, PHYSICAL - SCIE
# 33  1878-3686                ONCOLOGY - SCIE CELL BIOLOGY - SCIE
# 34  1759-5010            CARDIAC & CARDIOVASCULAR SYSTEMS - SCIE
# 35  1756-1833                MEDICINE, GENERAL & INTERNAL - SCIE
# 36  1097-4172  CELL BIOLOGY - SCIE BIOCHEMISTRY & MOLECULAR B...
# 37  1527-7755                                    ONCOLOGY - SCIE
# 38  2213-8595                  ENDOCRINOLOGY & METABOLISM - SCIE
# 39  1546-1696        BIOTECHNOLOGY & APPLIED MICROBIOLOGY - SCIE
# 40  2520-1131        ENGINEERING, ELECTRICAL & ELECTRONIC - SCIE
# 41  1756-8722                  HEMATOLOGY - SCIE ONCOLOGY - SCIE
# 42  1873-2208        MATERIALS SCIENCE, MULTIDISCIPLINARY - SCIE
# 43  1759-5037                  ENDOCRINOLOGY & METABOLISM - SCIE
# 44  1759-507X                        UROLOGY & NEPHROLOGY - SCIE
# 45  2522-5820  PHYSICS, MULTIDISCIPLINARY - SCIE PHYSICS, APP...
# 46  1460-4744                CHEMISTRY, MULTIDISCIPLINARY - SCIE
# 47  2468-1253               GASTROENTEROLOGY & HEPATOLOGY - SCIE
# 48  1524-4539  CARDIAC & CARDIOVASCULAR SYSTEMS - SCIE PERIPH...
# 49  1476-4660  CHEMISTRY, PHYSICAL - SCIE PHYSICS, APPLIED - ...
#
#                                             wos_index    jif 5_year_jif  \
# 0              SCIE - Science Citation Index Expanded  232.4        353
# 1              SCIE - Science Citation Index Expanded  103.3       99.1
# 2              SCIE - Science Citation Index Expanded  101.8      129.8
# 3              SCIE - Science Citation Index Expanded   90.2      128.7
# 4              SCIE - Science Citation Index Expanded   89.6         26
# 5              SCIE - Science Citation Index Expanded   88.5      104.8
# 6              SCIE - Science Citation Index Expanded   86.2       99.8
# 7              SCIE - Science Citation Index Expanded   82.2       89.9
# 8              SCIE - Science Citation Index Expanded   78.5       84.9
# 9              SCIE - Science Citation Index Expanded   71.5       73.7
# 10             SCIE - Science Citation Index Expanded   66.8         81
# 11  SCIE - Science Citation Index ExpandedSSCI - S...   65.8         60
# 12             SCIE - Science Citation Index Expanded   65.4       46.8
# 13             SCIE - Science Citation Index Expanded   62.5       52.4
# 14             SCIE - Science Citation Index Expanded   60.9       77.6
# 15             SCIE - Science Citation Index Expanded   60.6      104.8
# 16             SCIE - Science Citation Index Expanded   60.1       68.9
# 17             SCIE - Science Citation Index Expanded    N/A        N/A
# 18             ESCI - Emerging Sources Citation Index     56       66.9
# 19             SCIE - Science Citation Index Expanded   55.8       67.5
# 20             SCIE - Science Citation Index Expanded     55       64.7
# 21             SCIE - Science Citation Index Expanded   52.7       52.2
# 22             SCIE - Science Citation Index Expanded     52       57.1
# 23             SCIE - Science Citation Index Expanded   51.7       49.4
# 24             SCIE - Science Citation Index Expanded     51       72.4
# 25             SCIE - Science Citation Index Expanded     50       52.4
# 26             SCIE - Science Citation Index Expanded   49.8       34.1
# 27             SCIE - Science Citation Index Expanded   48.5         55
# 28             SCIE - Science Citation Index Expanded   46.7       42.8
# 29             SCIE - Science Citation Index Expanded   45.8       49.7
# 30             SCIE - Science Citation Index Expanded   45.5       56.2
# 31             SCIE - Science Citation Index Expanded   44.8       56.3
# 32             SCIE - Science Citation Index Expanded   44.6       47.4
# 33             SCIE - Science Citation Index Expanded   44.5       47.2
# 34             SCIE - Science Citation Index Expanded   44.2       52.9
# 35             SCIE - Science Citation Index Expanded   42.7       76.1
# 36             SCIE - Science Citation Index Expanded   42.5       48.9
# 37             SCIE - Science Citation Index Expanded   41.9       37.7
# 38             SCIE - Science Citation Index Expanded   41.8       41.7
# 39             SCIE - Science Citation Index Expanded   41.7       59.5
# 40             SCIE - Science Citation Index Expanded   40.9         42
# 41             SCIE - Science Citation Index Expanded   40.4       34.4
# 42             SCIE - Science Citation Index Expanded     40       44.8
# 43             SCIE - Science Citation Index Expanded     40         47
# 44             SCIE - Science Citation Index Expanded   39.8       44.5
# 45             SCIE - Science Citation Index Expanded   39.5       53.2
# 46             SCIE - Science Citation Index Expanded     39       50.1
# 47             SCIE - Science Citation Index Expanded   38.6         34
# 48             SCIE - Science Citation Index Expanded   38.6       35.9
# 49             SCIE - Science Citation Index Expanded   38.5       46.8
#
#                                    best_ranking percentage  \
# 0                                      ONCOLOGY      99.7%
# 1                                  MICROBIOLOGY      99.4%
# 2                       PHARMACOLOGY & PHARMACY      99.7%
# 3                                  CELL BIOLOGY      99.5%
# 4                          UROLOGY & NEPHROLOGY      99.2%
# 5                  MEDICINE, GENERAL & INTERNAL      99.7%
# 6                  NANOSCIENCE & NANOTECHNOLOGY      99.8%
# 7                                      ONCOLOGY      99.4%
# 8                  MEDICINE, GENERAL & INTERNAL      99.4%
# 9                GEOSCIENCES, MULTIDISCIPLINARY      99.7%
# 10                                     ONCOLOGY      99.1%
# 11                                   PSYCHIATRY      99.7%
# 12                                     ONCOLOGY      98.8%
# 13                  PHYSICS, PARTICLES & FIELDS      96.8%
# 14                                   IMMUNOLOGY      99.5%
# 15                 MEDICINE, GENERAL & INTERNAL      99.1%
# 16         MATERIALS SCIENCE, MULTIDISCIPLINARY      99.6%
# 17                                  Unavailable      99.8%
# 18                   MULTIDISCIPLINARY SCIENCES      99.3%
# 19                 CHEMISTRY, MULTIDISCIPLINARY      99.6%
# 20                 MEDICINE, GENERAL & INTERNAL      98.8%
# 21                                 CELL BIOLOGY      99.7%
# 22                          GENETICS & HEREDITY      99.5%
# 23                 CHEMISTRY, MULTIDISCIPLINARY      99.2%
# 24                GASTROENTEROLOGY & HEPATOLOGY      99.3%
# 25            MEDICINE, RESEARCH & EXPERIMENTAL      99.5%
# 26  PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH      99.5%
# 27                   MULTIDISCIPLINARY SCIENCES      98.5%
# 28                           TELECOMMUNICATIONS      99.6%
# 29                   MULTIDISCIPLINARY SCIENCES      97.8%
# 30                           CLINICAL NEUROLOGY      99.6%
# 31                   PHYSICS, MULTIDISCIPLINARY      99.1%
# 32                          CHEMISTRY, PHYSICAL      99.5%
# 33                                     ONCOLOGY      98.5%
# 34             CARDIAC & CARDIOVASCULAR SYSTEMS      99.6%
# 35                 MEDICINE, GENERAL & INTERNAL      98.5%
# 36                                 CELL BIOLOGY      99.1%
# 37                                     ONCOLOGY      98.2%
# 38                   ENDOCRINOLOGY & METABOLISM      99.5%
# 39         BIOTECHNOLOGY & APPLIED MICROBIOLOGY      98.9%
# 40         ENGINEERING, ELECTRICAL & ELECTRONIC      99.7%
# 41                                     ONCOLOGY        99%
# 42         MATERIALS SCIENCE, MULTIDISCIPLINARY      99.3%
# 43                   ENDOCRINOLOGY & METABOLISM        99%
# 44                         UROLOGY & NEPHROLOGY      98.5%
# 45                   PHYSICS, MULTIDISCIPLINARY      99.5%
# 46                 CHEMISTRY, MULTIDISCIPLINARY      98.7%
# 47                GASTROENTEROLOGY & HEPATOLOGY      98.6%
# 48                  PERIPHERAL VASCULAR DISEASE        99%
# 49                    PHYSICS, CONDENSED MATTER      98.7%
#
#                                           open_access          country  \
# 0   Fully Open Access ― It may take a publication ...    UNITED STATES
# 1                      Hybrid and Open Access Support          ENGLAND
# 2                      Hybrid and Open Access Support          ENGLAND
# 3                      Hybrid and Open Access Support          ENGLAND
# 4                                        Subscription    UNITED STATES
# 5                      Hybrid and Open Access Support          ENGLAND
# 6                                        Subscription          ENGLAND
# 7                      Hybrid and Open Access Support          ENGLAND
# 8                                        Subscription    UNITED STATES
# 9                                        Subscription          ENGLAND
# 10                                       Subscription          ENGLAND
# 11                                       Subscription            ITALY
# 12                     Hybrid and Open Access Support      NETHERLANDS
# 13  Fully Open Access ― It may take a publication ...          GERMANY
# 14                                       Subscription          ENGLAND
# 15                     Hybrid and Open Access Support          ENGLAND
# 16                     Hybrid and Open Access Support          ENGLAND
# 17  Fully Open Access ― It may take a publication ...    UNITED STATES
# 18                                       Subscription              N/A
# 19                     Hybrid and Open Access Support    UNITED STATES
# 20                                       Subscription    UNITED STATES
# 21  Fully Open Access ― It may take a publication ...  PEOPLES R CHINA
# 22                     Hybrid and Open Access Support          ENGLAND
# 23                     Hybrid and Open Access Support          ENGLAND
# 24                     Hybrid and Open Access Support    UNITED STATES
# 25                     Hybrid and Open Access Support    UNITED STATES
# 26                     Hybrid and Open Access Support    UNITED STATES
# 27                     Hybrid and Open Access Support          ENGLAND
# 28                     Hybrid and Open Access Support    UNITED STATES
# 29                     Hybrid and Open Access Support    UNITED STATES
# 30                     Hybrid and Open Access Support          ENGLAND
# 31                     Hybrid and Open Access Support    UNITED STATES
# 32                     Hybrid and Open Access Support          ENGLAND
# 33                     Hybrid and Open Access Support    UNITED STATES
# 34                     Hybrid and Open Access Support          ENGLAND
# 35  Fully Open Access ― It may take a publication ...          ENGLAND
# 36                     Hybrid and Open Access Support    UNITED STATES
# 37                     Hybrid and Open Access Support    UNITED STATES
# 38                     Hybrid and Open Access Support          ENGLAND
# 39                     Hybrid and Open Access Support    UNITED STATES
# 40                     Hybrid and Open Access Support          ENGLAND
# 41  Fully Open Access ― It may take a publication ...          ENGLAND
# 42                     Hybrid and Open Access Support          ENGLAND
# 43                     Hybrid and Open Access Support          ENGLAND
# 44                     Hybrid and Open Access Support    UNITED STATES
# 45                                       Subscription          ENGLAND
# 46                     Hybrid and Open Access Support          ENGLAND
# 47                     Hybrid and Open Access Support          ENGLAND
# 48                     Hybrid and Open Access Support    UNITED STATES
# 49                     Hybrid and Open Access Support          ENGLAND
#
#    wos_status publisher
# 0      Active       N/A
# 1      Active       N/A
# 2      Active       N/A
# 3      Active       N/A
# 4      Active       N/A
# 5      Active       N/A
# 6      Active       N/A
# 7      Active       N/A
# 8      Active       N/A
# 9      Active       N/A
# 10     Active       N/A
# 11     Active       N/A
# 12     Active       N/A
# 13     Active       N/A
# 14     Active       N/A
# 15     Active       N/A
# 16     Active       N/A
# 17     Active       N/A
# 18     Active       N/A
# 19     Active       N/A
# 20     Active       N/A
# 21     Active       N/A
# 22     Active       N/A
# 23     Active       N/A
# 24     Active       N/A
# 25     Active       N/A
# 26     Active       N/A
# 27     Active       N/A
# 28     Active       N/A
# 29     Active       N/A
# 30     Active       N/A
# 31     Active       N/A
# 32     Active       N/A
# 33     Active       N/A
# 34     Active       N/A
# 35     Active       N/A
# 36     Active       N/A
# 37     Active       N/A
# 38     Active       N/A
# 39     Active       N/A
# 40     Active       N/A
# 41     Active       N/A
# 42     Active       N/A
# 43     Active       N/A
# 44     Active       N/A
# 45     Active       N/A
# 46     Active       N/A
# 47     Active       N/A
# 48     Active       N/A
# 49     Active       N/A
# Done! Saved 50 journals to journals_data.csv

# %%
print(df['publisher'])
