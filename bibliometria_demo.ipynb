# %% [markdown]
# # Install and import

# %%
# !pip install -i https://test.pypi.org/simple/ bibliometria==0.1.1
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting bibliometria==0.1.1
#   Downloading https://test-files.pythonhosted.org/packages/96/55/2eebd1798f6621eba06e11b6f66a647df036393105d3c9139b5781552105/bibliometria-0.1.1-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.12/dist-packages (from bibliometria==0.1.1) (2.2.2)
# INFO: pip is looking at multiple versions of bibliometria to determine which version is compatible with other requirements. This could take a while.
# ERROR: Could not find a version that satisfies the requirement rapidfuzz>=3.0 (from bibliometria) (from versions: 0.10.0)
# ERROR: No matching distribution found for rapidfuzz>=3.0

# %%
# !pip install -i https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple bibliometria==0.1.1
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple
# Collecting bibliometria==0.1.1
#   Using cached https://test-files.pythonhosted.org/packages/96/55/2eebd1798f6621eba06e11b6f66a647df036393105d3c9139b5781552105/bibliometria-0.1.1-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.12/dist-packages (from bibliometria==0.1.1) (2.2.2)
# Collecting rapidfuzz>=3.0 (from bibliometria==0.1.1)
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->bibliometria==0.1.1) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->bibliometria==0.1.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->bibliometria==0.1.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->bibliometria==0.1.1) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5->bibliometria==0.1.1) (1.17.0)
# Downloading https://test-files.pythonhosted.org/packages/96/55/2eebd1798f6621eba06e11b6f66a647df036393105d3c9139b5781552105/bibliometria-0.1.1-py3-none-any.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 9.7 MB/s eta 0:00:00
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 37.9 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, bibliometria
# Successfully installed bibliometria-0.1.1 rapidfuzz-3.14.3

# %%
import bibliometria as bm

# %% [markdown]
# # title_matches

# %%
df_matches = bm.title_matches('Language Resources and Evaluation', limit=5, score_cutoff=60)
df_matches
# Out:
#                            raw_title                         matched_title  \
# 0  Language Resources and Evaluation     Language Resources and Evaluation
# 1  Language Resources and Evaluation     Language Resources and Evaluation
# 2  Language Resources and Evaluation                Language and Education
# 3  Language Resources and Evaluation                Language and Education
# 4  Language Resources and Evaluation  Genetic Resources and Crop Evolution
#
#    match_score          source                                 title  \
# 0       100.00       SCImagojr     Language Resources and Evaluation
# 1       100.00  Web of Science     Language Resources and Evaluation
# 2        72.73       SCImagojr                Language and Education
# 3        72.73  Web of Science                Language and Education
# 4        72.46       SCImagojr  Genetic Resources and Crop Evolution
#
#                  issn      eissn    sjr sjr_best_quartile wos_quartile
# 0            1574020X        NaN  0,477                Q1          NaN
# 1           1574-0218  1574-0218    NaN               NaN           Q3
# 2            09500782        NaN  1,213                Q1          NaN
# 3           1747-7581  1747-7581    NaN               NaN           Q1
# 4  09259864, 15735109        NaN  0,410                Q2          NaN

# %% [markdown]
# # title_best_match

# %%
best = bm.title_best_match('Language Resources and Evaluation')
best
# Out:
# raw_title            Language Resources and Evaluation
# matched_title        Language Resources and Evaluation
# match_score                                      100.0
# source                                       SCImagojr
# title                Language Resources and Evaluation
# issn                                          1574020X
# sjr                                              0,477
# sjr_best_quartile                                   Q1
# dtype: object

# %% [markdown]
# # journal_metrics

# %%
metrics = bm.journal_metrics("Journal of Linguistics", query_type="title")
metrics
# Out:
# sjr                  0,902
# sjr_best_quartile       Q1
# h_index                 50
# wos_quartile            Q2
# wos_jif                1.2
# wos_jif_5_year         1.7
# Name: Journal of Linguistics, dtype: object

# %%
metrics_issn = bm.journal_metrics("26738945", query_type="issn")
metrics_issn
# Out:
# sjr                  0,370
# sjr_best_quartile       Q1
# h_index                  8
# wos_quartile            Q3
# wos_jif                1.4
# wos_jif_5_year         1.6
# Name: Architecture, dtype: object

# %% [markdown]
# # journal_info

# %%
info = bm.journal_info("Journal of Linguistics", query_type="title")
info
# Out:
#                        title                   query query_type  \
# 5679  Journal of Linguistics  Journal of Linguistics      title
#
#      source_primary           matched_title  match_score  rank sourceid  \
# 5679            df1  Journal of Linguistics        100.0  5680   145253
#
#          type                issn  ... abbreviation      eissn  \
# 5679  journal  14697742, 00222267  ...   J LINGUIST  1469-7742
#
#                                               category  \
# 5679  LANGUAGE & LINGUISTICS - AHCI LINGUISTICS - SSCI
#
#                                               wos_index wos_jif  \
# 5679  SSCI - Social Sciences Citation IndexAHCI - Ar...     1.2
#
#      wos_jif_5_year best_ranking percentage wos_status wos_quartile
# 5679            1.7  LINGUISTICS      62.4%     Active           Q2
#
# [1 rows x 43 columns]

# %%
info = bm.journal_info("26738945", query_type="issn")
info
# Out:
#               title     query query_type source_primary matched_title  \
# 14573  Architecture  26738945       issn      SCImagojr  Architecture
#
#        match_score   rank     sourceid     type      issn  ...  \
# 14573          100  14574  21101238221  journal  26738945  ...
#
#              abbreviation      eissn category wos_index wos_jif  \
# 14573  ARCHITECTURE-BASEL  2673-8945      NaN       NaN     1.4
#
#       wos_jif_5_year best_ranking percentage wos_status wos_quartile
# 14573            1.6  Unavailable      30.5%     Active           Q3
#
# [1 rows x 43 columns]
